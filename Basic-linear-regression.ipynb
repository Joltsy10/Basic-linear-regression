# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('data.csv')
x = df.iloc[:,:1].values
y = df.iloc[:,-1].values
mymodel = []
l = 0.0003

# %%
w = 0
b = 0

# %%
def costfunc():
    predictions = w * x + b
    return np.sum((predictions - y) ** 2) / (2 * len(x))

def gradient_descent():
    global w,b
    prediction = w * x + b
    error = prediction - y
    temp_w = np.dot(error,x)/len(x)
    temp_b = np.sum(error)/len(x)
    w = w - l * temp_w
    b = b - l * temp_b

# %%
for n in range(1000):
    gradient_descent()
costfunc()
# Out:
# np.float64(nan)

# %%
mymodel = w * x + b

# %%
plt.scatter(x,y)
plt.plot(x,mymodel)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
